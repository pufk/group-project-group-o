# %% [markdown]
# # COMP257 Project

# %% [markdown]
# # Final work:

# %%
# working code to be put here

# %% [markdown]
# # Kyle:

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/help_tickets.csv')

df = df.sort_values(by=['Number'], ascending=True)
#TASK0475834
print("Shape: "+ str(df.shape))
print(df['Number'].iloc[0])
df.head()
# Out:
# Shape: (22729, 22)
# Export stopped due to excessive size. Use CSV for a complete export.
#                                                   Number           Created  \
# 22728  Export stopped due to excessive size. Use CSV ...               NaN
# 22727                                        TASK0452994  02/08/2018 16:20
# 22726                                        TASK0452995  02/08/2018 16:22
# 22725                                        TASK0452996  02/08/2018 16:22
# 22724                                        TASK0452997  02/08/2018 16:23
#
#                 Updated                                  Short description  \
# 22728               NaN                                                NaN
# 22727  02/08/2018 17:02  Other ICT Request: Setting up a Uni shared dri...
# 22726  07/08/2018 07:05     Other ICT Request: Call forwarding to a mobile
# 22725  02/08/2018 16:22       eStudent: request to reset eStudent password
# 22724  02/08/2018 16:44                              OneID: Account Locked
#
#                  State   Assignment group Active            Closed  \
# 22728              NaN                NaN    NaN               NaN
# 22727  Closed Complete  Human Sciences IT  False  02/08/2018 17:02
# 22726  Closed Complete     IT Fixed Voice  False  07/08/2018 07:05
# 22725  Closed Complete    IT Service Desk  False  02/08/2018 16:22
# 22724  Closed Complete    IT Service Desk  False  02/08/2018 16:44
#
#       Description  Domain     ...       \
# 22728         NaN     NaN     ...
# 22727         NaN  global     ...
# 22726         NaN  global     ...
# 22725         NaN  global     ...
# 22724         NaN  global     ...
#
#                                  Faculty / Office  \
# 22728                                         NaN
# 22727                   Faculty of Human Sciences
# 22726  DVC - Corporate Engagement and Advancement
# 22725                                     Student
# 22724                                     Student
#
#                                               Location     Task type Updates  \
# 22728                                              NaN           NaN     NaN
# 22727  Level 3, Australian Hearing Hub, 16 University   Catalog Task     2.0
# 22726                   4 Research Park Drive, Level 2  Catalog Task    12.0
# 22725                                              NaN  Catalog Task     2.0
# 22724                                              NaN  Catalog Task     1.0
#
#       Business duration  Business duration (days)  Company  Escalation  \
# 22728               NaN                       NaN      NaN         NaN
# 22727            2520.0                      0.07      NaN      Normal
# 22726          178680.0                      2.16      NaN      Normal
# 22725               0.0                      0.00      NaN      Normal
# 22724            1260.0                      0.04      NaN      Normal
#
#        Time worked Total effort
# 22728          NaN          NaN
# 22727          0.0          0.0
# 22726          0.0          0.0
# 22725          0.0          0.0
# 22724          0.0          0.0
#
# [5 rows x 22 columns]

# %% [markdown]
# # Hey kasun im thinking you put your stuff below this line try not to have overlapping variables i will put mine above when we have working code copy past it to a final section
# # ---------------------------------------------------------------------------------------
# # Kasun:
