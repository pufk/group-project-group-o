# %% [markdown]
# # COMP257 Project

# %% [markdown]
# # Final work:

# %%
# working code to be put here

# %% [markdown]
# # Kyle:

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/help_tickets.csv')

df.head()
# Out:
#         Number           Created           Updated  \
# 0  TASK0475834  06/10/2018 12:17  06/10/2018 12:20
# 1  TASK0475833  06/10/2018 12:12  06/10/2018 12:16
# 2  TASK0475832  06/10/2018 12:08  06/10/2018 12:08
# 3  TASK0475831  06/10/2018 12:05  06/10/2018 12:05
# 4  TASK0475830  06/10/2018 12:04  06/10/2018 12:04
#
#                                    Short description            State  \
# 0  Other ICT Request: Please grant access to SMUA...  Closed Complete
# 1  Office365 Mail: FW: Optus Macquarie University...             Open
# 2                OneID: OneID password reset request  Closed Complete
# 3                OneID: OneID password reset request  Closed Complete
# 4       eStudent: request to reset eStudent password  Closed Complete
#
#   Assignment group Active            Closed Description  Domain     ...       \
# 0  IT Service Desk  False  06/10/2018 12:20         NaN  global     ...
# 1  IT Service Desk   True               NaN         NaN  global     ...
# 2  IT Service Desk  False  06/10/2018 12:08         NaN  global     ...
# 3  IT Service Desk  False  06/10/2018 12:05         NaN  global     ...
# 4  IT Service Desk  False  06/10/2018 12:04         NaN  global     ...
#
#                                   Faculty / Office  \
# 0                Faculty of Business and Economics
# 1  Deputy Vice Chancellor (Students and Registrar)
# 2  Deputy Vice Chancellor (Students and Registrar)
# 3                                          Student
# 4                                          Student
#
#                       Location     Task type Updates Business duration  \
# 0  6 Management Drive, Level 1  Catalog Task     2.0               0.0
# 1                          NaN  Catalog Task     1.0               0.0
# 2                          NaN  Catalog Task     2.0               0.0
# 3                          NaN  Catalog Task     2.0               0.0
# 4                          NaN  Catalog Task     2.0               0.0
#
#    Business duration (days)  Company  Escalation  Time worked Total effort
# 0                       0.0      NaN      Normal          0.0          0.0
# 1                       NaN      NaN      Normal          0.0          0.0
# 2                       0.0      NaN      Normal          0.0          0.0
# 3                       0.0      NaN      Normal          0.0          0.0
# 4                       0.0      NaN      Normal          0.0          0.0
#
# [5 rows x 22 columns]

# %% [markdown]
# # Hey kasun im thinking you put your stuff below this line try not to have overlapping variables i will put mine above when we have working code copy past it to a final section
# # ---------------------------------------------------------------------------------------
# # Kasun:
